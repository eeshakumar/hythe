# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib inline
from pathlib import Path
import os
num_steps = 100
sns.set_style("ticks")
sns.color_palette("Set2")

plt.rcParams['figure.figsize'] = (25.0, 10.0)
plt.rcParams['font.family'] = "serif"
sns.set(font_scale=2)
sns.set_style("ticks")

# %%
demo_df_thdi64 = "/home/ekumar/output/experiments/exp_e934f8dd-797e-45f2-97bb-20187a4a8f4e/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_df_thdi64)
print(df.head(10))
# df = df[:100000]


# learned_df = "/home/ekumar/master_thesis/results/training/december/iqn/lfd/feb/exp_iqn_pre_exp_loaded_demo/demonstrations/learned_dataframe"
# df2 = pd.read_pickle(learned_df)
# df.head(10), df2.head(10)

# %%
demo_df_th = "/home/ekumar/output/experiments/exp_2474ef6b-d395-4410-9f6c-320028603322/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_df_th)
df.head(10)
# df = df[:100000]


# learned_df = "/home/ekumar/master_thesis/results/training/december/iqn/lfd/feb/exp_iqn_pre_exp_loaded_demo/demonstrations/learned_dataframe"
# df2 = pd.read_pickle(learned_df)
# df.head(10), df2.head(10)

# %%
demo_df_di64 = "/home/ekumar/output/experiments/exp_a191fb9b-e4cc-479a-95d7-14b2180c72f2/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_df_di64)
# df.head(10)
# df = df[:100000]


learned_df = "/home/ekumar/master_thesis/results/training/december/iqn/lfd/feb/fixed/exp_iqn_fixed_onoff_bedi64/demonstrations/learned_dataframe"
df2 = pd.read_pickle(learned_df)
df.head(10), df2.head(10)
# Out:
# (        pos_x        pos_y  orientation  velocity  action  is_demo
#  0  980.659853  1008.267883     3.069821  7.333671       4        1
#  1  979.286073  1008.356262     3.098977  6.333672       4        1
#  2  978.109805  1008.389649     3.128214  5.333672       4        1
#  3  977.133062  1008.395203     3.144154  4.333673       4        1
#  4  976.356318  1008.389893     3.153157  3.333674       5        1
#  5  975.690063  1008.367187     3.203213  3.333674       0        1
#  6  975.025755  1008.311157     3.253269  3.333674       5        1
#  7  974.365047  1008.221924     3.303325  3.333674       1        1
#  8  973.692018  1008.096131     3.354732  3.533674       1        1
#  9  972.987667  1007.925598     3.409144  3.733674       5        1,
#          pos_x        pos_y  orientation  velocity  action  is_demo
#  0  962.550168  1007.688965     3.278260  9.227409       0        1
#  1  960.733647  1007.366455     3.364959  9.227409       3        1
# ...

# %%
import matplotlib.patches as  mpatches
plt.figure()
sns.scatterplot(data=df[-10000:], x='pos_x', y='pos_y', hue='velocity', palette='Blues')
plt.title('Demonstrator States Learned Offline', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
plt.legend(fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('demo_states_lfd_iqn_bedi64_off.pdf')
plt.figure()
sns.scatterplot(data=df2[-10000:], x='pos_x', y='pos_y', hue='velocity', palette='Reds')
plt.title('Exploration States Learned Online', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
plt.legend(fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('demo_states_lfd_iqn_bedi64_on.pdf')
# concatenated = pd.concat([df.assign(phase='offline'), df2.assign(phase='online')])
# print(concatenated.head(10))
# plt.figure()
# sns.scatterplot(data=concatenated, x='pos_x', y='pos_y', hue='phase', alpha=0.2)
concatenated = pd.concat([df.assign(phase='demonstrated')[-20000:], df2.assign(phase='self-explored')[-20000:]])
# print(concatenated.head(10))
plt.figure()
sns.kdeplot(data=df[-20000:], x='pos_x', y='pos_y', cmap='Blues', alpha=.7, fill=True)
sns.kdeplot(data=df2[-20000:], x='pos_x', y='pos_y', cmap='Reds', alpha=.7, fill=True)
plt.title('Overlay of Explored States: Demonstrator vs. LfD-BO-IQN', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
# plot.legend(fontsize=30, loc='lower right')
handles = [mpatches.Patch(facecolor=plt.cm.Blues(100), label="demonstrated"),
           mpatches.Patch(facecolor=plt.cm.Reds(100), label="self-explored")]
plt.legend(handles=handles, fontsize=30, loc='lower right')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('overlay_kde_lfd_iqn_bedi64.pdf')
# Out:
# <img src="data:image/png;base64,..." width="2500">
# <img src="data:image/png;base64,..." width="2500">
# <img src="data:image/png;base64,..." width="2500">

# %%
demo_df_lfd_iqn = "/home/ekumar/output/experiments/exp_0de9a416-7b06-419c-b6e4-b47df846ee68/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_df_lfd_iqn)
# df = df[:100000]


learned_df = "/home/ekumar/master_thesis/results/training/december/iqn/lfd/feb/fixed/exp_iqn_fixed_onoff/demonstrations/learned_dataframe"
df2 = pd.read_pickle(learned_df)
df.head(10), df2.head(10)
# Out:
# (        pos_x        pos_y  orientation  velocity  action  is_demo
#  0  980.659853  1008.267883     3.069821  7.333671       4        1
#  1  979.286073  1008.356262     3.098977  6.333672       4        1
#  2  978.109805  1008.389649     3.128214  5.333672       4        1
#  3  977.133062  1008.395203     3.144154  4.333673       4        1
#  4  976.356318  1008.389893     3.153157  3.333674       5        1
#  5  975.690063  1008.367187     3.203213  3.333674       0        1
#  6  975.025755  1008.311157     3.253269  3.333674       5        1
#  7  974.365047  1008.221924     3.303325  3.333674       1        1
#  8  973.692018  1008.096131     3.354732  3.533674       1        1
#  9  972.987667  1007.925598     3.409144  3.733674       0        1,
#          pos_x        pos_y  orientation  velocity  action  is_demo
#  0  966.486514  1006.044189     3.241807  4.393817       0        1
#  1  980.659853  1008.267883     3.069821  6.820412       4        1
# ...

# %%
plt.figure()
sns.scatterplot(data=df[-10000:], x='pos_x', y='pos_y', hue='velocity', palette='Blues')
plt.title('Demonstrator States Learned Offline', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
plt.legend(fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('demo_states_lfd_iqn_off.pdf')
plt.figure()
sns.scatterplot(data=df2[-10000:], x='pos_x', y='pos_y', hue='velocity', palette='Reds')
plt.title('Exploration States Learned Online', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
plt.legend(fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('demo_states_lfd_iqn_on.pdf')
# concatenated = pd.concat([df.assign(phase='offline'), df2.assign(phase='online')])
# print(concatenated.head(10))
# plt.figure()
# sns.scatterplot(data=concatenated, x='pos_x', y='pos_y', hue='phase', alpha=0.2)
concatenated = pd.concat([df.assign(phase='demonstrated')[-10000:], df2.assign(phase='self-explored')[-10000:]])
print(concatenated.head(10))
plt.figure()
sns.kdeplot(data=df[-20000:], x='pos_x', y='pos_y', cmap='Blues', alpha=.7, fill=True)
sns.kdeplot(data=df2[-20000:], x='pos_x', y='pos_y', cmap='Reds', alpha=.7, fill=True)
plt.title('Overlay of Explored States: Demonstrator vs. LfD-IQN', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
handles = [mpatches.Patch(facecolor=plt.cm.Blues(100), label="demonstrated"),
           mpatches.Patch(facecolor=plt.cm.Reds(100), label="self-explored")]
plt.legend(handles=handles, fontsize=30, loc='lower right')
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('overlay_kde_lfd_iqn.pdf')
# Out:
# <img src="data:image/png;base64,..." width="2500">
# <img src="data:image/png;base64,..." width="2500">
#              pos_x        pos_y  orientation  velocity  action  is_demo  \
# 122849  976.408502  1008.370605     3.205096  4.156564       3        1
# 122850  975.616573  1008.298950     3.264807  3.756564       5        1
# 122851  974.873538  1008.187744     3.321214  3.756564       3        1
# 122852  974.173164  1008.043030     3.374918  3.356564       0        1
# 122853  973.523862  1007.873047     3.425320  3.356564       1        1
# 122854  972.866886  1007.664734     3.477072  3.556564       1        1
# 122855  972.184447  1007.407776     3.531111  3.756564       5        1
# 122856  971.493220  1007.113403     3.551808  3.756564       7        1
# 122857  970.770624  1006.821533     3.493287  4.069047       1        1
# 122858  969.982115  1006.557007     3.430836  4.269046       1        1
#
#                phase
# 122849  demonstrated
# 122850  demonstrated
# ...

# %%
plt.figure()
sns.scatterplot(data=df[-10000:], x='pos_x', y='pos_y', hue='velocity')
plt.title('Demonstrator States learned Offline', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
plt.legend(fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('demo_states_lfd_iqn_off.svg')
plt.figure()
sns.scatterplot(data=df2[-10000:], x='pos_x', y='pos_y', hue='velocity')
plt.title('Exploration States learned online', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
plt.legend(fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('demo_states_lfd_iqn_on.svg')
# concatenated = pd.concat([df.assign(phase='offline'), df2.assign(phase='online')])
# print(concatenated.head(10))
# plt.figure()
# sns.scatterplot(data=concatenated, x='pos_x', y='pos_y', hue='phase', alpha=0.2)

# %%
# plt.figure()
# sns.kdeplot(data=df[-10000:], x='pos_x', y='pos_y', fill=True)
# plt.title('Demonstrator States learned Offline', fontsize=30)
# plt.xlabel('Position X', fontsize=30)
# plt.ylabel('Position Y', fontsize=30)
# # plt.legend(fontsize=30)
# plt.xticks(fontsize=30)
# plt.yticks(fontsize=30)
# plt.savefig('demo_states_lfd_iqn_off_kde.svg')
# plt.figure()
# sns.kdeplot(data=df2[-10000:], x='pos_x', y='pos_y', fill=True)
# plt.title('Exploration States learned Online', fontsize=30)
# plt.xlabel('Position X', fontsize=30)
# plt.ylabel('Position Y', fontsize=30)
# # plt.legend(fontsize=30)
# plt.xticks(fontsize=30)
# plt.yticks(fontsize=30)
# plt.savefig('demo_states_lfd_iqn_on_kde.svg')
concatenated = pd.concat([df.assign(phase='offline')[-10000:], df2.assign(phase='online')[-10000:]])
print(concatenated.head(10))
plt.figure()
sns.kdeplot(data=concatenated, x='pos_x', y='pos_y', hue='phase', alpha=.5, linewidth=0, fill=True)
plt.title('Overlay of explored states', fontsize=30)
plt.xlabel('Position X', fontsize=30)
plt.ylabel('Position Y', fontsize=30)
# plt.legend(fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.savefig('overlay_kde_lfd_iqn.svg')

# %%
demo_dataframe = "/home/ekumar/output/experiments/exp_aa3feb5b-f98e-4318-9bb8-c183eaad4c3a/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_dataframe)
# df = df[:100000]
print(df.shape)
df.head(10)

# demo_dataframe = "/home/ekumar/output/experiments/exp_b72b9960-c5a1-4458-becc-0bc79f555571/demonstrations/demo_dataframe"
# df2 = pd.read_pickle(demo_dataframe)
# # df2 = df2[:100000]

# %%
# df['is_learned'] = 0
# df2['is_learned'] = 0

# df = df.append(df2)
# print(df.shape)

# df.columns = ['pos_x', 'pos_y', 'velocity', 'orientation_theta']
df.rename(columns={0:'pos_x', 1:'pos_y', 2:'velocity', 3:'orientation_theta'})
plt.figure()
sns.scatterplot(data=df, x='pos_x', y='pos_y', size='velocity', hue='velocity')
# plt.figure()
# sns.scatterplot(x=df2[0], y=df2[1], hue=df2.is_learned, alpha=0.1)

# %%
plt.figure()
sns.kdeplot(x=df[0], y=df[1], fill=True)

plt.figure()
sns.kdeplot(x=df2[0], y=df2[1], fill=True)

# %%
learned_dataframe = "/home/ekumar/master_thesis/results/training/december/iqn/exp_mid_dense_lbnw_copy/states_dataframe"
df2 = pd.read_pickle(learned_dataframe)
print(df2.shape)

# %%
plt.figure()
sns.kdeplot(x=df2[0], y=df2[1], fill=True)

plt.figure()
sns.scatterplot(x=df2[0], y=df2[1], alpha=0.1)

# %%
learned_dataframe = "/home/ekumar/master_thesis/results/training/december/iqn/exp_iqn_lbnw_copy/states_dataframe"
df2 = pd.read_pickle(learned_dataframe)

df['learner'] = 'mcts'
df2['learner'] = 'vanilla iqn'

print(df2.shape)
df2.head(10)

# %%
df['learner'] = 'mcts'
df2['learner'] = 'vanilla iqn'

df = df.append(df2)
plt.figure()
sns.kdeplot(x=df[0], y=df[1], fill=False, hue=df.learner, common_norm=False)

# plt.figure()
# sns.scatterplot(x=df2[0], y=df2[1], alpha=0.1)

# %%
learned_dataframe = "/home/ekumar/master_thesis/results/training/december/iqn/exp_van2_lbnw_ld_copy/states_dataframe"
df2 = pd.read_pickle(learned_dataframe)
print(df2.shape)

plt.figure()
sns.kdeplot(x=df2[0], y=df2[1], fill=True)

# plt.figure()
# sns.scatterplot(x=df2[0], y=df2[1], alpha=0.1)

# %%
demo_dataframe = "/home/ekumar/output/experiments//exp_b72b9960-c5a1-4458-becc-0bc79f555571/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_dataframe)
df = df[:100000]
print(df.shape)
df.head(10)

learned_dataframe = "/home/ekumar/master_thesis/results/training/december/iqn/exp_van2_lbnw_ld_copy/states_dataframe"
df2 = pd.read_pickle(learned_dataframe)
print(df2.shape)
df.head(10), df2.head(10)

learned_dataframe = "/home/ekumar/master_thesis/results/training/december/iqn/exp_iqn_lbnw_copy/states_dataframe"
df3 = pd.read_pickle(learned_dataframe)
print(df3.shape)
df.head(10), df2.head(10), df3.head(10)

# %%
plt.figure()
sns.scatterplot(data=df, x='pos_x', y='pos_y', hue='action')

# %%
# df2.rename(columns={0:'pos_x', 1:'pos_y', 2:'velocity', 3:'orientation', 4: 'action'})
# print(df2.columns)
plt.figure()
sns.scatterplot(data=df2, x='pos_x', y='pos_y', hue='action')

# %%
# df2.rename(columns={0:'pos_x', 1:'pos_y', 2:'velocity', 3:'orientation', 4: 'action'})
# print(df2.columns)
plt.figure()
sns.scatterplot(data=df3, x='pos_x', y='pos_y', hue='action')

# %%
df['learner'] = 'mcts'
df2['learner'] = 'beliefs iqn'
df3['learner'] = 'vanilla iqn'

df_all = df.append(df2)
df_all = df_all.append(df3)
plt.figure()
sns.kdeplot(data=df_all, x='pos_x', y='pos_y', fill=False, hue=df_all.learner, common_norm=False)

# plt.figure()
# sns.scatterplot(x=df2[0], y=df2[1], alpha=0.1)

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df['pos_x']
y = df['pos_y']
z = df['velocity']

ax.scatter(x, y, z, c=df['action'])
# plt.colorbar()
plt.show()

# %%
learned_dataframe = "/home/ekumar/master_thesis/results/training/december/iqn/lfd/stats/online/exp_online_new_2s_be_di64/states_dataframe"
df2 = pd.read_pickle(learned_dataframe)
print(df2.shape)
df2.head(10), df2[df2['is_demo'] == 0].count()

# %%
learned_dataframe = "/home/ekumar/master_thesis/results/training/december/iqn/lfd/exp_default_params_online/states_dataframe"
df2 = pd.read_pickle(learned_dataframe)
print(df2.shape)
df2.head(10)
plt.figure()
sns.scatterplot(data=df2, x=df2[0], y=df2[1])

# %%
plt.figure()
sns.scatterplot(data=df2, x=df2[0], y=df2[1])
# plt.xlim([933, 1000.6])
# plt.ylim([1000.2, 1015])

# %%
learned_dataframe = "/home/ekumar/output/experiments/exp_fa03c699-bfbf-4587-8ef7-f062f13188b0/states_dataframe"
df2 = pd.read_pickle(learned_dataframe)
print(df2.shape)
df2.head(10), df2[df2['is_demo'] == 1].count()

# %%
demo_dataframe = "/home/ekumar/output/experiments/exp_2a2405c4-74ca-48b9-8705-fdd51b173003/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_dataframe)
# df = df[:100000]
print(df.shape)
df.head(10)

# %%
demo_dataframe = "/home/ekumar/output/experiments/exp_f0198f6b-611b-4d77-aef7-677542c330ac/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_dataframe)
# df = df[:100000]
print(df.shape)
df.head(10)

# %%
learned_dataframe = "/home/ekumar/output/experiments/exp_f0198f6b-611b-4d77-aef7-677542c330ac/demonstrations/learned_dataframe"
df2 = pd.read_pickle(learned_dataframe)
print(df2.shape)
df2.head(10)

# %%
plt.figure()
sns.scatterplot(data=df2, x='pos_x', y='pos_y', hue='is_demo')

# %%
demo_dataframe = "/home/ekumar/output/experiments/exp_8b5b0dfc-3320-4033-8a7d-9446a60061cf/demonstrations/demo_dataframe"
df = pd.read_pickle(demo_dataframe)
# df = df[:100000]
print(df.shape)
df.head(10)
df['exp'] = 'mcts'


learned_dataframe = "/home/ekumar/output/experiments/exp_25aa2acd-def4-4203-82c9-bf6dc06f7d7e/demonstrations/learned_dataframe"
df2 = pd.read_pickle(learned_dataframe)
print(df2.shape)
df2.head(10), df2.tail(10)

df2['exp'] = 'mixed'

# %%
plt.figure()
sns.scatterplot(data=df2, x='pos_x', y='pos_y', hue='is_demo')

# %%
df = df.append(df2)
plt.figure()
sns.scatterplot(data=df, x='pos_x', y='pos_y', hue='is_demo', size='exp')
